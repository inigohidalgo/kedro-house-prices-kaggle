# %%
# %load_ext kedro.extras.extensions.ipython
# %reload_kedro

# %load_ext autoreload
# %autoreload 2
# Out:
# The kedro.extras.extensions.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.extras.extensions.ipython
# 2022-04-24 19:05:15,445 - root - INFO - No path argument was provided. Using: /Users/inigo/Programming/kedro-projects/kaggle-house-prices
# 2022-04-24 19:05:15,619 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2022-04-24 19:05:15,865 - root - INFO - ** Kedro project Kaggle House Prices
# 2022-04-24 19:05:15,867 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2022-04-24 19:05:15,881 - root - INFO - Registered line magic `run_viz`
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.environ["KAGGLE_username"] = "inigohrey"
os.environ["KAGGLE_key"] = "4da08432f758ed693cd24af8de591bd1"

from kaggle.api.kaggle_api_extended import KaggleApi
import pandas as pd

# %%
from kaggle_house_prices.utils.utils import set_cwd

# %%
api = KaggleApi()
api.authenticate()

# %%
api.competition_list_files("house-prices-advanced-regression-techniques")
# Out:
# [sample_submission.csv, test.csv, train.csv, data_description.txt]

# %%
# Out:
# sample_submission.csv

# %%
# !pwd
# Out:
# /Users/inigo/Programming/kedro-projects/kaggle-house-prices/notebooks

# %%
target_path = Path("../data/01_raw/")

# %%
# !pwd
# Out:
# /Users/inigo/Programming/kedro-projects/kaggle-house-prices/notebooks

# %%
catalog.list()
# Out:
# ['house_prices', 'intermediate_house_prices', 'parameters']

# %%
import logging
log = logging.getLogger()

# %%
def load_kaggle_dataset(dataset, competition=None):
    with tempfile.TemporaryDirectory() as temp_dir:
        temp_path = Path(temp_dir)
        log.debug(str(temp_path))
        log.debug("ee")
        with set_cwd(temp_dir):
            _log_msg = f"Downloading dataset {dataset}"
            if competition is not None:
                _log_msg += f" from competition {competition}"
            log.info(_log_msg)
            api.competition_download_file(competition, dataset, quiet=True)
        df=pd.read_csv(temp_path/"train.csv")
    
    return df

#catalog.save("house_prices", df)

# %%
log.setLevel(logging.INFO)

# %%
house_prices = load_kaggle_dataset('train.csv', competition='house-prices-advanced-regression-techniques')
# Out:
# 2022-04-24 11:31:08,665 - root - INFO - Downloading dataset train.csv from competition house-prices-advanced-regression-techniques

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    temp_path = Path(temp_dir)
    with set_cwd(temp_dir):
        log.info("Downloading {'train.csv'}")
        api.competition_download_file('house-prices-advanced-regression-techniques','train.csv', quiet=True)
    df=pd.read_csv(temp_path/"train.csv")

catalog.save("house_prices", df)
# Out:
# 2022-04-24 11:11:06,227 - kedro.io.data_catalog - INFO - Saving data to `house_prices` (CSVDataSet)...

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    temp_path = Path(temp_dir)
    api.competition_download_file('house-prices-advanced-regression-techniques','train.csv', path=temp_path)
    df=pd.read_csv(temp_path/"train.csv")
    df.to_csv(target_path/"house_prices_train.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j9/7db4144x63v82qk83vb6rclh0000gn/T/ipykernel_20778/3150793964.py in <cell line: 1>()
#       1 with tempfile.TemporaryDirectory() as temp_dir:
#       2     temp_path = Path(temp_dir)
# ----> 3     api.competition_download_file('house-prices-advanced-regression-techniques','train.csv', path=temp_path)
#       4     df=pd.read_csv(temp_path/"train.csv")
#       5     df.to_csv(target_path/"house_prices_train.csv", index=False)
#
# NameError: name 'api' is not defined

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
api.competition_download_files('house-prices-advanced-regression-techniques')
print("hello")
# Out:
# hello

# %%
from kaggle_house_prices.api import kaggle

# %%
dataset = kaggle.KaggleDataSet(credentials={"user": "inigohrey", "key": "4da08432f758ed693cd24af8de591bd1"})

# %%
dataset.load_competition_dataset('house-prices-advanced-regression-techniques', 'train.csv', index_col="Id")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
dataset._download_single_competition_file('house-prices-advanced-regression-techniques', "data_description.txt", "../docs/reference")
# Out:
# PosixPath('../docs/reference/data_description.txt')

# %%
os.environ["KAGGLE_user"]
# Out:
# 'inigohrey'
