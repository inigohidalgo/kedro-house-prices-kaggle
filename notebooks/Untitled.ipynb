# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of kaggle_house_prices.utils.modeling failed: Traceback (most recent call last):
#   File "/Users/inigo/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/inigo/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/inigo/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/inigo/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
# ...

# %%
import kaggle_house_prices

# %%
from kaggle_house_prices.utils import modeling

# %%
x = modeling.GenericModel("regression", "rforest")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j9/7db4144x63v82qk83vb6rclh0000gn/T/ipykernel_89330/544548615.py in <cell line: 1>()
# ----> 1 x = modeling.GenericModel("regression", "rforest")
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
x.model_class()
# Out:
# RandomForestRegressor()

# %%
import sklearn.linear_model

# %%
sklearn.linear_model.LogisticRegression
# Out:
# sklearn.linear_model._logistic.LogisticRegression
