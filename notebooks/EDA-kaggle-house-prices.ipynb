# %%
import kedro

# %%
import kaggle

# %%
# %load_ext kedro.extras.extensions.ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# 2022-05-01 01:31:52,511 - root - INFO - Updated path to Kedro project: /Users/inigo/Programming/kedro-projects/kaggle-house-prices
# 2022-05-01 01:31:52,735 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2022-05-01 01:31:54,101 - root - INFO - ** Kedro project Kaggle House Prices
# 2022-05-01 01:31:54,103 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2022-05-01 01:31:56,324 - root - INFO - Registered line magic `run_viz`
# /Users/inigo/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/IPython/extensions/autoreload.py:121: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload

# %%
from pathlib import Path

# %%
import pandas as pd
import plotly.express as px

# %%
# %reload_kedro
# Out:
# 2022-05-01 09:31:20,038 - root - INFO - No path argument was provided. Using: /Users/inigo/Programming/kedro-projects/kaggle-house-prices
# 2022-05-01 09:31:20,223 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2022-05-01 09:31:20,514 - kedro.config.common - INFO - Config from path `/Users/inigo/Programming/kedro-projects/kaggle-house-prices/conf/local` will override the following existing top-level config keys: root
# 2022-05-01 09:31:20,531 - root - INFO - ** Kedro project Kaggle House Prices
# 2022-05-01 09:31:20,532 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2022-05-01 09:31:20,548 - root - INFO - Registered line magic `run_viz`

# %%
int_hp = catalog.load("intermediate_house_prices")
# Out:
# 2022-05-01 01:31:57,168 - kedro.io.data_catalog - INFO - Loading data from `intermediate_house_prices` (ParquetDataSet)...

# %%
int_hp["MSSubClass"].astype(str).value_counts().sort_index()
# Out:
# 120     87
# 160     63
# 180     10
# 190     30
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# Name: MSSubClass, dtype: int64

# %%
int_hp["PavedDrive"].astype(str).value_counts().sort_index()
# Out:
# N      90
# P      30
# Y    1340
# Name: PavedDrive, dtype: int64

# %%
catalog.list()
# Out:
# ['house_prices', 'intermediate_house_prices', 'parameters']

# %%
house_prices = catalog.load("house_prices")
# Out:
# 2022-04-24 11:02:23,552 - kedro.io.data_catalog - INFO - Loading data from `house_prices` (CSVDataSet)...

# %%
intermediate_house_prices = catalog.load("intermediate_house_prices")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j9/7db4144x63v82qk83vb6rclh0000gn/T/ipykernel_42787/2726034020.py in <cell line: 1>()
# ----> 1 intermediate_house_prices = catalog.load("intermediate_house_prices")
#
# NameError: name 'catalog' is not defined

# %%
intermediate_house_prices["PavedDrive"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j9/7db4144x63v82qk83vb6rclh0000gn/T/ipykernel_42787/1042585825.py in <cell line: 1>()
# ----> 1 intermediate_house_prices["PavedDrive"].value_counts()
#
# NameError: name 'intermediate_house_prices' is not defined

# %%
session.run("dp")
# Out:
# 2022-05-01 01:33:43,760 - kedro.framework.session.session - INFO - ** Kedro project kaggle-house-prices
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j9/7db4144x63v82qk83vb6rclh0000gn/T/ipykernel_42787/205790996.py in <cell line: 1>()
# ----> 1 session.run("dp")
#
# ~/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/kedro/framework/session/session.py in run(self, pipeline_name, tags, runner, node_names, from_nodes, to_nodes, from_inputs, to_outputs, load_versions)
#     357
#     358         try:
# --> 359             pipeline = pipelines[name]
#     360         except KeyError as exc:
#     361             raise ValueError(
#
# ~/miniconda3/envs/kaggle-house-prices/lib/python3.8/site-packages/kedro/framework/project/__init__.py in inner(self, *args, **kwargs)
#      90     # pylint: disable=protected-access
# ...

# %%
catalog.load("params:model_options.model_name")
# Out:
# 2022-05-01 01:42:12,098 - kedro.io.data_catalog - INFO - Loading data from `params:model_options.model_name` (MemoryDataSet)...
# 'rforest'

# %%
catalog.list()
# Out:
# ['house_prices',
#  'intermediate_house_prices',
#  'model_input_table',
#  'trained_model_object',
#  'parameters',
#  'params:model_options',
#  'params:model_options.preprocess_params',
#  'params:model_options.preprocess_params.drop_columns',
#  'params:model_options.model_init_params',
#  'params:model_options.model_init_params.n_jobs',
#  'params:model_options.target_name',
#  'params:model_options.model_name']

# %%
df = catalog.load("model_input_table")
# Out:
# 2022-05-01 01:58:25,638 - kedro.io.data_catalog - INFO - Loading data from `model_input_table` (ParquetDataSet)...

# %%
df.isna().mean().sort_values()
# Out:
# MSSubClass       0.000000
# BedroomAbvGr     0.000000
# KitchenAbvGr     0.000000
# TotRmsAbvGrd     0.000000
# Fireplaces       0.000000
# GarageCars       0.000000
# GarageArea       0.000000
# HalfBath         0.000000
# WoodDeckSF       0.000000
# EnclosedPorch    0.000000
# 3SsnPorch        0.000000
# ScreenPorch      0.000000
# PoolArea         0.000000
# MiscVal          0.000000
# MoSold           0.000000
# OpenPorchSF      0.000000
# YrSold           0.000000
# FullBath         0.000000
# BsmtFullBath     0.000000
# LotArea          0.000000
# OverallQual      0.000000
# OverallCond      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# BsmtHalfBath     0.000000
# BsmtFinSF2       0.000000
# BsmtFinSF1       0.000000
# TotalBsmtSF      0.000000
# 1stFlrSF         0.000000
# 2ndFlrSF         0.000000
# LowQualFinSF     0.000000
# GrLivArea        0.000000
# BsmtUnfSF        0.000000
# SalePrice        0.000000
# MasVnrArea       0.005479
# ...
