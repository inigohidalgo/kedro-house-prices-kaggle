# %%
import optuna

# %%
from types import SimpleNamespace

# %%
import sklearn

# %%
x = SimpleNamespace()

# %%
x.a=1

# %%
x.a
# Out:
# 1

# %%
x.__get__()

# %%
def run_optuna_sweep(model, config):
